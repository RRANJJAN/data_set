# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Workspace/Repos/ravi.giri007@gmail.com/data_set/Sales.csv")

df.display()

# %%
# Cell 2: Kitne rows hain dekho
print(f"Total rows: {df.count()}")
print(f"Total columns: {len(df.columns)}")

# %%
df.printSchema()
