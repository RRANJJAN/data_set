# %%
# ============================================
# Project: XYZ E-Commerce Sales Analytics
# Author: Ravi Ranjan
# Created: 2026-03-19
# Purpose: Project configuration and database setup
# ============================================

BRONZE_DB = "bronze"
SILVER_DB = "silver"
GOLD_DB = "gold"

SOURCE_PATH = "/Workspace/Repos/ravi.giri007@gmail.com/data_set/Sales.csv"

print("=" * 50)
print("⚙️ PROJECT CONFIGURATION")
print("=" * 50)
print(f"Bronze DB : {BRONZE_DB}")
print(f"Silver DB : {SILVER_DB}")
print(f"Gold DB   : {GOLD_DB}")
print(f"Source    : {SOURCE_PATH}")

# %%
# Create Databases
spark.sql(f"CREATE DATABASE IF NOT EXISTS {BRONZE_DB}")
spark.sql(f"CREATE DATABASE IF NOT EXISTS {SILVER_DB}")
spark.sql(f"CREATE DATABASE IF NOT EXISTS {GOLD_DB}")

print("\n✅ Databases Created: bronze, silver, gold")

# %%
# Verify Databases
print("\n📊 Available Databases:")
display(spark.sql("SHOW DATABASES"))
